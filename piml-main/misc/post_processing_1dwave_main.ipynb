# %%
import pandas as pd

# %%
df = pd.read_csv("results_int_points.csv")

# %%
df
# Out:
#       Point ID      area  lambda_wave_equation  Points_0  Points_1  Points_2  \
# 0          874  0.000997                     1  3.139760         0         0
# 1          966  0.000997                     1  3.139620         0         0
# 2         2908  0.000997                     1  3.139350         0         0
# 3          373  0.000997                     1  3.139150         0         0
# 4          119  0.000997                     1  3.138390         0         0
# ...        ...       ...                   ...       ...       ...       ...
# 3145       245  0.000997                     1  0.004663         0         0
# 3146      2858  0.000997                     1  0.004523         0         0
# 3147       211  0.000997                     1  0.003787         0         0
# 3148      1041  0.000997                     1  0.003288         0         0
# 3149       487  0.000997                     1  0.002215         0         0
#
#       Points_Magnitude  pred_wave_equation       sdf         t  \
# 0             3.139760            0.000766  0.001829  2.370280
# 1             3.139620           -0.000162  0.001969  4.088070
# 2             3.139350            0.000853  0.002239  3.463190
# 3             3.139150           -0.001540  0.002446  4.779970
# 4             3.138390            0.001593  0.003199  1.588590
# ...                ...                 ...       ...       ...
# 3145          0.004663            0.000448  0.004663  0.167765
# 3146          0.004523            0.001989  0.004523  5.448380
# 3147          0.003787            0.000069  0.003787  4.776190
# 3148          0.003288           -0.000923  0.003288  5.976600
# 3149          0.002215           -0.002052  0.002215  0.944773
#
#       true_wave_equation         u      u__t   u__t__t      u__x   u__x__x  \
# 0                      0 -0.000450 -0.004627 -0.000353  0.017032 -0.001119
# 1                      0 -0.003080  0.000150 -0.002477  1.395030 -0.002315
# 2                      0 -0.003796  0.000200  0.004053  1.268030  0.003201
# 3                      0 -0.003702  0.000601  0.004551  0.925218  0.006091
# 4                      0  0.003444 -0.002230 -0.008651 -0.980972 -0.010244
# ...                  ...       ...       ...       ...       ...       ...
# 3145                   0  0.005359  0.002893 -0.008395  1.153520 -0.008843
# 3146                   0 -0.001033  0.010814  0.012009 -0.078235  0.010020
# 3147                   0 -0.004258  0.001042  0.005078 -0.928988  0.005009
# 3148                   0  0.003243  0.000366 -0.060380  0.654045 -0.059457
# 3149                   0  0.002718  0.000061 -0.000045  1.395850  0.002007
#
#       wave_equation
# 0          0.000766
# 1         -0.000162
# 2          0.000853
# 3         -0.001540
# 4          0.001593
# ...             ...
# 3145       0.000448
# 3146       0.001989
# 3147       0.000069
# 3148      -0.000923
# 3149      -0.002052
#
# [3150 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(50,6))
ax = fig.add_subplot(111,projection='3d')

ax.plot_trisurf(df['Points_0'],df['t'],df['u'], cmap='rainbow')

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')
ax.set_zlabel('u_axis')
# Out:
# Text(0.5, 0, 'u_axis')

# %%
fig, ax = plt.subplots(figsize=(12,6))

scatter = ax.scatter(df['Points_0'],df['t'],c=df['u'], cmap='rainbow', marker='o',s=50)

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')

fig.colorbar(scatter, ax=ax, label='u_axis')

# %%
df2 = pd.read_csv("results_valid.csv")

# %%
df2
# Out:
#         Point ID  Points_0  Points_1  Points_2  Points_Magnitude    pred_u  \
# 0            314      3.14         0         0              3.14  0.001285
# 1            629      3.14         0         0              3.14  0.001305
# 2            944      3.14         0         0              3.14  0.001323
# 3           1259      3.14         0         0              3.14  0.001340
# 4           1574      3.14         0         0              3.14  0.001356
# ...          ...       ...       ...       ...               ...       ...
# 198130    196560      0.00         0         0              0.00 -0.002713
# 198131    196875      0.00         0         0              0.00 -0.002997
# 198132    197190      0.00         0         0              0.00 -0.003293
# 198133    197505      0.00         0         0              0.00 -0.003602
# 198134    197820      0.00         0         0              0.00 -0.003924
#
#            t    true_u
# 0       0.00  0.001593
# 1       0.01  0.001608
# 2       0.02  0.001624
# 3       0.03  0.001640
# 4       0.04  0.001655
# ...      ...       ...
# 198130  6.24  0.000000
# 198131  6.25  0.000000
# 198132  6.26  0.000000
# 198133  6.27  0.000000
# 198134  6.28  0.000000
#
# [198135 rows x 8 columns]

# %%
df2['Error']=  df2['pred_u'] - df2['true_u']

# %%
df2
# Out:
#         Point ID  Points_0  Points_1  Points_2  Points_Magnitude    pred_u  \
# 0            314      3.14         0         0              3.14  0.001285
# 1            629      3.14         0         0              3.14  0.001305
# 2            944      3.14         0         0              3.14  0.001323
# 3           1259      3.14         0         0              3.14  0.001340
# 4           1574      3.14         0         0              3.14  0.001356
# ...          ...       ...       ...       ...               ...       ...
# 198130    196560      0.00         0         0              0.00 -0.002713
# 198131    196875      0.00         0         0              0.00 -0.002997
# 198132    197190      0.00         0         0              0.00 -0.003293
# 198133    197505      0.00         0         0              0.00 -0.003602
# 198134    197820      0.00         0         0              0.00 -0.003924
#
#            t    true_u     Error
# 0       0.00  0.001593 -0.000307
# 1       0.01  0.001608 -0.000304
# 2       0.02  0.001624 -0.000301
# 3       0.03  0.001640 -0.000300
# 4       0.04  0.001655 -0.000299
# ...      ...       ...       ...
# 198130  6.24  0.000000 -0.002713
# 198131  6.25  0.000000 -0.002997
# 198132  6.26  0.000000 -0.003293
# 198133  6.27  0.000000 -0.003602
# 198134  6.28  0.000000 -0.003924
#
# [198135 rows x 9 columns]

# %%
fig = plt.figure(figsize=(50,6))
ax = fig.add_subplot(111,projection='3d')

ax.plot_trisurf(df2['Points_0'],df2['t'],df2['pred_u'], cmap='rainbow')

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')
ax.set_zlabel('u_axis')
# Out:
# Text(0.5, 0, 'u_axis')

# %%
fig = plt.figure(figsize=(50,6))
ax = fig.add_subplot(111,projection='3d')

ax.plot_trisurf(df2['Points_0'],df2['t'],df2['true_u'], cmap='rainbow')

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')
ax.set_zlabel('u_axis')
# Out:
# Text(0.5, 0, 'u_axis')

# %%
fig = plt.figure(figsize=(50,6))
ax = fig.add_subplot(111,projection='3d')

ax.plot_trisurf(df2['Points_0'],df2['t'],df2['Error'], cmap='rainbow')

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')
ax.set_zlabel('u_axis')
# Out:
# Text(0.5, 0, 'u_axis')

# %%
fig, ax = plt.subplots(figsize=(12,6))

scatter = ax.scatter(df2['Points_0'],df2['t'],c=df2['Error'], cmap='rainbow', marker='o',s=0.5)

ax.set_xlabel('x_axis')
ax.set_ylabel('t_axis')

fig.colorbar(scatter, ax=ax, label='u_axis')
